# %% [markdown]
# # South African Educational System Project

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\sandi\Downloads\education_zaf.csv")
df.head()
# Out:
#     Country Name   Country ISO3        Year  \
# 0  #country+name  #country+code  #date+year
# 1   South Africa            ZAF        2010
# 2   South Africa            ZAF        2005
# 3   South Africa            ZAF        2000
# 4   South Africa            ZAF        1995
#
#                                       Indicator Name       Indicator Code  \
# 0                                    #indicator+name      #indicator+code
# 1  Barro-Lee: Percentage of female population age...  BAR.NOED.1519.FE.ZS
# 2  Barro-Lee: Percentage of female population age...  BAR.NOED.1519.FE.ZS
# 3  Barro-Lee: Percentage of female population age...  BAR.NOED.1519.FE.ZS
# 4  Barro-Lee: Percentage of female population age...  BAR.NOED.1519.FE.ZS
#
#                   Value
# 0  #indicator+value+num
# 1                   0.3
# 2                  0.51
# 3                  3.13
# 4                  2.19

# %%
df=df.drop(df.index[0]).reset_index(drop=True)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14586 entries, 0 to 14585
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    14586 non-null  object
#  1   Country ISO3    14586 non-null  object
#  2   Year            14586 non-null  object
#  3   Indicator Name  14586 non-null  object
#  4   Indicator Code  14586 non-null  object
#  5   Value           14586 non-null  object
# dtypes: object(6)
# memory usage: 683.8+ KB

# %%
df['Year']= pd.to_numeric(df['Year'],errors= 'coerce')
df['Value']=pd.to_numeric(df['Value'], errors= 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14586 entries, 0 to 14585
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    14586 non-null  object
#  1   Country ISO3    14586 non-null  object
#  2   Year            14586 non-null  int64
#  3   Indicator Name  14586 non-null  object
#  4   Indicator Code  14586 non-null  object
#  5   Value           14586 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 683.8+ KB

# %%
df['Indicator Name'].unique()
# Out:
# array(['Barro-Lee: Percentage of female population age 15-19 with no education',
#        'Barro-Lee: Percentage of population age 15-19 with no education',
#        'Barro-Lee: Percentage of female population age 15+ with no education',
#        'Barro-Lee: Percentage of population age 15+ with no education',
#        'Barro-Lee: Percentage of female population age 20-24 with no education',
#        'Barro-Lee: Percentage of population age 20-24 with no education',
#        'Barro-Lee: Percentage of female population age 25-29 with no education',
#        'Barro-Lee: Percentage of population age 25-29 with no education',
#        'Barro-Lee: Percentage of female population age 25+ with no education',
#        'Barro-Lee: Percentage of population age 25+ with no education',
#        'Barro-Lee: Percentage of female population age 30-34 with no education',
#        'Barro-Lee: Percentage of population age 30-34 with no education',
# ...

# %%
reading_scale_indicator=['PIRLS: Mean performance on the reading scale, male',
       'SACMEQ: Mean performance on the mathematics scale',
       'SACMEQ: Mean performance on the mathematics scale, female',
       'SACMEQ: Mean performance on the mathematics scale, male',
       'SACMEQ: Mean performance on the reading scale, total',
       'SACMEQ: Mean performance on the reading scale, female',
       'SACMEQ: Mean performance on the reading scale, male']

graduates_indicator=['Percentage of graduates from tertiary education graduating from Agriculture, Forestry, Fisheries and Veterinary programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Education programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Engineering, Manufacturing and Construction programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Health and Welfare programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Arts and Humanities programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from programmes in unspecified fields, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Natural Sciences, Mathematics and Statistics programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Social Sciences, Journalism and Information programmes, both sexes (%)',
       'Percentage of graduates from tertiary education graduating from Services programmes, both sexes (%)']

youth_illiterate_indicator= ['Youth illiterate population, 15-24 years, both sexes (number)',
       'Youth illiterate population, 15-24 years, female (number)',
       'Youth illiterate population, 15-24 years, male (number)']

# %%
education_attainment_indicator=["Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)",
       "Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)",
       "Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)",
       'Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)',
       'Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)',
       'Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)',
       "Educational attainment, at least Master's or equivalent, population 25+, female (%) (cumulative)",
       "Educational attainment, at least Master's or equivalent, population 25+, male (%) (cumulative)",
       "Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)"]

Female_indicator=['Female share of graduates in Agriculture, Forestry, Fisheries and Veterinary programmes, tertiary (%)',
       'Female share of graduates in Education programmes, tertiary (%)',
       'Female share of graduates in Engineering, Manufacturing and Construction programmes, tertiary (%)',
       'Female share of graduates in Health and Welfare programmes, tertiary (%)',
       'Female share of graduates in Arts and Humanities programmes, tertiary (%)',
       'Female share of graduates in unknown or unspecified fields, tertiary (%)',
       'Female share of graduates in Natural Sciences, Mathematics and Statistics programmes, tertiary (%)',
       'Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)',
       'Female share of graduates in Social Sciences, Journalism and Information programmes, tertiary (%)',
       'Female share of graduates in Services programmes, tertiary (%)',
       'Female share of graduates in Business, Administration and Law programmes, tertiary (%)',
       'Female share of graduates in Information and Communication Technologies programmes, tertiary (%)',
       'Female share of graduates in other fields than Science, Technology, Engineering and Mathematics programmes, tertiary (%)']

Government_Expenditure=['Expenditure on primary education (% of government expenditure on education)',
                        'Expenditure on secondary education (% of government expenditure on education)',
                        'Expenditure on tertiary education (% of government expenditure on education)']

# %%
Repetition_rate_indicator=['Repetition rate in Grade 1 of primary education, female (%)',
       'Repetition rate in Grade 1 of primary education, male (%)','Repetition rate in Grade 2 of primary education, female (%)',
       'Repetition rate in Grade 2 of primary education, male (%)','Repetition rate in Grade 3 of primary education, female (%)',
       'Repetition rate in Grade 3 of primary education, male (%)','Repetition rate in Grade 4 of primary education, female (%)',
       'Repetition rate in Grade 4 of primary education, male (%)','Repetition rate in Grade 5 of primary education, female (%)',
       'Repetition rate in Grade 5 of primary education, male (%)','Repetition rate in Grade 6 of primary education, female (%)',
       'Repetition rate in Grade 6 of primary education, male (%)','Repetition rate in Grade 7 of primary education, female (%)',
       'Repetition rate in Grade 7 of primary education, male (%)']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14586 entries, 0 to 14585
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    14586 non-null  object
#  1   Country ISO3    14586 non-null  object
#  2   Year            14586 non-null  int64
#  3   Indicator Name  14586 non-null  object
#  4   Indicator Code  14586 non-null  object
#  5   Value           14586 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 683.8+ KB

# %%
ReadingScale_df= df[df['Indicator Name'].isin(reading_scale_indicator)]
ReadingScale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 3188 to 3202
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    15 non-null     object
#  1   Country ISO3    15 non-null     object
#  2   Year            15 non-null     int64
#  3   Indicator Name  15 non-null     object
#  4   Indicator Code  15 non-null     object
#  5   Value           15 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 840.0+ bytes

# %%
ReadingScale_df['Indicator Name'].unique()
# Out:
# array(['PIRLS: Mean performance on the reading scale, male',
#        'SACMEQ: Mean performance on the mathematics scale',
#        'SACMEQ: Mean performance on the mathematics scale, female',
#        'SACMEQ: Mean performance on the mathematics scale, male',
#        'SACMEQ: Mean performance on the reading scale, total',
#        'SACMEQ: Mean performance on the reading scale, female',
#        'SACMEQ: Mean performance on the reading scale, male'],
#       dtype=object)

# %%
ReadingScale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 3188 to 3202
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    15 non-null     object
#  1   Country ISO3    15 non-null     object
#  2   Year            15 non-null     int64
#  3   Indicator Name  15 non-null     object
#  4   Indicator Code  15 non-null     object
#  5   Value           15 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 840.0+ bytes

# %%
Female_scale= df[df['Indicator Name'].isin(Female_indicator)]

# %%
Female_scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 14324 to 14386
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    63 non-null     object
#  1   Country ISO3    63 non-null     object
#  2   Year            63 non-null     int64
#  3   Indicator Name  63 non-null     object
#  4   Indicator Code  63 non-null     object
#  5   Value           63 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.4+ KB

# %%
graduates_df= df[df['Indicator Name'].isin(graduates_indicator)]

# %%
graduates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 3755 to 3800
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    46 non-null     object
#  1   Country ISO3    46 non-null     object
#  2   Year            46 non-null     int64
#  3   Indicator Name  46 non-null     object
#  4   Indicator Code  46 non-null     object
#  5   Value           46 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
education_df=df[df['Indicator Name'].isin(education_attainment_indicator)]

# %%
education_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 13214 to 13327
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    114 non-null    object
#  1   Country ISO3    114 non-null    object
#  2   Year            114 non-null    int64
#  3   Indicator Name  114 non-null    object
#  4   Indicator Code  114 non-null    object
#  5   Value           114 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.2+ KB

# %%
youth_df= df[df['Indicator Name'].isin(youth_illiterate_indicator)]
youth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 9878 to 9907
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    30 non-null     object
#  1   Country ISO3    30 non-null     object
#  2   Year            30 non-null     int64
#  3   Indicator Name  30 non-null     object
#  4   Indicator Code  30 non-null     object
#  5   Value           30 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.6+ KB

# %%
repetition_df= df[df['Indicator Name'].isin(Repetition_rate_indicator)]
repetition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, 10314 to 10488
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    126 non-null    object
#  1   Country ISO3    126 non-null    object
#  2   Year            126 non-null    int64
#  3   Indicator Name  126 non-null    object
#  4   Indicator Code  126 non-null    object
#  5   Value           126 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.9+ KB

# %%
expenditure_df= df[df['Indicator Name'].isin(Government_Expenditure)]
expenditure_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 13561 to 13644
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    62 non-null     object
#  1   Country ISO3    62 non-null     object
#  2   Year            62 non-null     int64
#  3   Indicator Name  62 non-null     object
#  4   Indicator Code  62 non-null     object
#  5   Value           62 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.4+ KB

# %%
ReadingScale_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\Python Files.csv",index= False)

# %%
Female_scale.to_csv(r"C:\Users\sandi\OneDrive\Desktop\Python Files.csv",index= False)

# %%
graduates_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\filing.csv",index= False)

# %%
expenditure_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\filing.csv",index= False)

# %%
repetition_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\filing.csv",index= False)

# %%
education_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\filing.csv",index= False)

# %%
youth_df.to_csv(r"C:\Users\sandi\OneDrive\Desktop\filing.csv",index= False)
